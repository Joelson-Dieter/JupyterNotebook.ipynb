# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import pandas as pd
from time import sleep
service = Service (r"C:\Users\Administrator\OneDrive\Documents\Data_Entry\PythonDOCS\chromedriver.exe")
driver = webdriver.Chrome (service=service)
driver.get(r"https://www.flipkart.com/")
driver.maximize_window()

input_search = driver.find_elements(By.XPATH,"(//input[@class='Pke_EE'])")

search_button = driver.find_elements(By.XPATH,"(//button[@class='_2iLD__'])")

input_search[0].send_keys("Kids,girls dresses")

sleep(5)

search_button[0].click()

# %%
product_name = driver.find_elements(By.XPATH,"(//div[@class='syl9yP'])")
old_price = driver.find_elements(By.XPATH,"(//div[@class='yRaY8j'])")
new_price = driver.find_elements(By.XPATH,"(//div[@class='Nx9bqj'])")
discounts = driver.find_elements(By.XPATH,"(//div[@class='UkUFwK'])")

# %%
# Find the minimum length of the lists to avoid index errors
min_length = min(len(product_name), len(old_price), len(new_price), len(discounts))

# Store data in a list first (efficient way to build DataFrame)
data = []
for i in range(min_length):  
    data.append({
        'Product name': product_name[i].text,
        'Old price': old_price[i].text,
        'New price': new_price[i].text,
        'Discounts': discounts[i].text
        
    })  

# Convert the list to a Pandas DataFrame
df_kids = pd.DataFrame(data)

# Display the DataFrame
print(df_kids)
# Out:
#                 Product name Old price New price Discounts
# 0               Miss & Chief    ₹1,999      ₹449   77% off
# 1            STUMBLE FASHION      ₹999      ₹220   77% off
# 2          newday collection    ₹1,399      ₹433   69% off
# 3               Miss & Chief    ₹1,999      ₹499   75% off
# 4                   starword    ₹1,999      ₹299   85% off
# 5               Miss & Chief    ₹1,999      ₹429   78% off
# 6               Miss & Chief    ₹1,999      ₹499   75% off
# 7               Miss & Chief    ₹1,999      ₹499   75% off
# 8                      NEYSA    ₹1,199      ₹399   66% off
# 9        LUCKY FASHION WORLD    ₹1,199      ₹290   75% off
# 10              Miss & Chief    ₹1,999      ₹449   77% off
# 11              Miss & Chief    ₹1,999      ₹399   80% off
# 12         PURNKAMAAY TRENDZ    ₹1,299      ₹279   78% off
# 13               THERAJSTORE    ₹1,857      ₹225   87% off
# 14              Miss & Chief    ₹1,999      ₹499   75% off
# 15                PN fashion      ₹999      ₹249   75% off
# 16                 SPAMitude    ₹1,499      ₹279   81% off
# 17           VILLATA FASHION    ₹1,999      ₹295   85% off
# 18  MUSKAN BEAUTY COLLECTION      ₹599      ₹249   58% off
# 19              Miss & Chief    ₹1,999      ₹449   77% off
# 20            dhvani fashion    ₹1,999      ₹319   84% off
# 21       Jayshree Enterprise    ₹1,999      ₹499   75% off
# 22                     Ethit    ₹1,999      ₹319   84% off
# 23         PURNKAMAAY TRENDZ    ₹1,299      ₹279   78% off
# 24             SK JJ DRESSES    ₹1,279      ₹169   86% off
# 25             SK JJ DRESSES    ₹1,299      ₹169   86% off
# 26         PURNKAMAAY TRENDZ    ₹1,299      ₹279   78% off
# 27                 Chandrika      ₹844      ₹179   78% off
# 28                   newsifa      ₹999      ₹246   75% off
# 29                   Billion    ₹1,499      ₹499   66% off
# 30           STUMBLE FASHION      ₹999      ₹298   70% off
# 31                Bongprince      ₹999      ₹379   62% off
# 32          MT SAHIN DRESSES      ₹999      ₹240   75% off
# 33                    Trenzy    ₹1,259      ₹191   84% off
# 34                     FASSY    ₹1,499      ₹369   75% off
# 35             ER LIFE STYLE    ₹1,200      ₹205   82% off
# 36           VILLATA FASHION    ₹1,999      ₹295   85% off
# 37                  MILILIAM    ₹1,299      ₹245   81% off
# 38               THERAJSTORE    ₹1,999      ₹249   87% off
# 39             SK JJ DRESSES    ₹1,299      ₹229   82% off

# %%
df_kids
# Out:
#                 Product name Old price New price Discounts
# 0               Miss & Chief    ₹1,999      ₹449   77% off
# 1            STUMBLE FASHION      ₹999      ₹220   77% off
# 2          newday collection    ₹1,399      ₹433   69% off
# 3               Miss & Chief    ₹1,999      ₹499   75% off
# 4                   starword    ₹1,999      ₹299   85% off
# 5               Miss & Chief    ₹1,999      ₹429   78% off
# 6               Miss & Chief    ₹1,999      ₹499   75% off
# 7               Miss & Chief    ₹1,999      ₹499   75% off
# 8                      NEYSA    ₹1,199      ₹399   66% off
# 9        LUCKY FASHION WORLD    ₹1,199      ₹290   75% off
# 10              Miss & Chief    ₹1,999      ₹449   77% off
# 11              Miss & Chief    ₹1,999      ₹399   80% off
# 12         PURNKAMAAY TRENDZ    ₹1,299      ₹279   78% off
# 13               THERAJSTORE    ₹1,857      ₹225   87% off
# 14              Miss & Chief    ₹1,999      ₹499   75% off
# 15                PN fashion      ₹999      ₹249   75% off
# 16                 SPAMitude    ₹1,499      ₹279   81% off
# 17           VILLATA FASHION    ₹1,999      ₹295   85% off
# 18  MUSKAN BEAUTY COLLECTION      ₹599      ₹249   58% off
# 19              Miss & Chief    ₹1,999      ₹449   77% off
# 20            dhvani fashion    ₹1,999      ₹319   84% off
# 21       Jayshree Enterprise    ₹1,999      ₹499   75% off
# 22                     Ethit    ₹1,999      ₹319   84% off
# 23         PURNKAMAAY TRENDZ    ₹1,299      ₹279   78% off
# 24             SK JJ DRESSES    ₹1,279      ₹169   86% off
# 25             SK JJ DRESSES    ₹1,299      ₹169   86% off
# 26         PURNKAMAAY TRENDZ    ₹1,299      ₹279   78% off
# 27                 Chandrika      ₹844      ₹179   78% off
# 28                   newsifa      ₹999      ₹246   75% off
# 29                   Billion    ₹1,499      ₹499   66% off
# 30           STUMBLE FASHION      ₹999      ₹298   70% off
# 31                Bongprince      ₹999      ₹379   62% off
# 32          MT SAHIN DRESSES      ₹999      ₹240   75% off
# 33                    Trenzy    ₹1,259      ₹191   84% off
# 34                     FASSY    ₹1,499      ₹369   75% off
# 35             ER LIFE STYLE    ₹1,200      ₹205   82% off
# 36           VILLATA FASHION    ₹1,999      ₹295   85% off
# 37                  MILILIAM    ₹1,299      ₹245   81% off
# 38               THERAJSTORE    ₹1,999      ₹249   87% off
# 39             SK JJ DRESSES    ₹1,299      ₹229   82% off
