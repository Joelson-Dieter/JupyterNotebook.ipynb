# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
web="https://www.flipkart.com/home-kitchen/kitchen-appliances/pr?sid=j9e,m38&otracker=categorytree"
path=r"C:\Users\Administrator\OneDrive\Documents\Data_Entry\PythonDOCS\chromedriver.exe"
service=Service(executable_path=path)
driver=webdriver.Chrome(service=service)
driver.get(web)
time.sleep(2)
titles=[]
colors=[]
stars=[]
reviews=[]
discounts=[]
prices=[]

# %%
for i in range(548):
  title=driver.find_elements(By.XPATH,"(//a[@class='wjcEIp'])")
  color=driver.find_elements(By.XPATH,"(//div[@class='NqpwHC'])")
  star=driver.find_elements(By.XPATH,"(//div[@class='XQDdHH'])")
  review=driver.find_elements(By.XPATH,"(//span[@class='Wphh3N'])")
  discount=driver.find_elements(By.XPATH,"(//div[@class='UkUFwK'])")
  price=driver.find_elements(By.XPATH,"(//div[@class='Nx9bqj'])")
  for t in title:
    titles.append(t.text)
  for c in color:
    colors.append(c.text)
  for s in star:
    stars.append(s.text)
  for r in review:
    reviews.append(r.text)
  for d in discount:
    discounts.append(d.text)
  for p in price:
    prices.append(p.text)
next_button=driver.find_element(By.XPATH,"(//a[@class='_9QVEpD'])")
next_button.click()
time.sleep(2)

# %%
min_len=min(len(titles),len(colors),len(stars),len(reviews),len(discounts),len(prices))
titles=titles[:min_len]
colors=colors[:min_len]
stars=stars[:min_len]
reviews=reviews[:min_len]
discounts=discounts[:min_len]
prices=prices[:min_len]

# %%
df=pd.DataFrame({'Titles':titles,
                 'Colors':colors,
                 'Stars':stars,
                 'Reviews':reviews,
                 'Discounts':discounts,
                 'Prices':prices})

# %%
print(df)
# Out:
#                                                   Titles  \
# 0      Midea TORRINO,WQP12-5201F Free Standing 13 Pla...
# 1      Venus Electronic Digital Kitchen Weight Machin...
# 2      Midea MDWTT0802D(B) Free Standing 8 Place Sett...
# 3                 Sansui Plus 500 W Juicer Mixer Grinder
# 4                 Lifelong Power Pro 500 W Mixer Grinder
# ...                                                  ...
# 18627  Moonstruck mixi blue - 4 jar 750 W Juicer Mixe...
# 18628  SONALEX Weight Machine 10kg Scale Digital For ...
# 18629  HAVELLS GHFMGCIK050 / GHFMGCIE050 500 W Mixer ...
# 18630  Flipkart SmartBuy Storm Max PowerChef 500 W Ju...
# 18631  CHHOKRA Digital 10kg x 1g Kitchen Scale Balanc...
#
#                                                   Colors Stars     Reviews  \
# 0                                                  White   3.9     (2,480)
# 1                     Allure Plus | 3 Jars | Black, Blue   3.9     (2,199)
# 2                     Power Pro - LLMG20 | 3 Jars | Blue   3.9     (2,480)
# 3            ACGM-DS500W BLEND | 4 Jars | Black and Blue   4.1    (56,010)
# 4         Rapid plus / Rapid Plus 5J | 5 Jars | Ink Blue   4.1  (1,61,416)
# ...                                                  ...   ...         ...
# 18627  Black, Infrared Induction 2000 Watt (All Utens...   4.1     (9,294)
# 18628                                 MS23A3513AK, BLACK   4.4    (12,051)
# 18629                               Plus | 1 Jar | Black     4    (28,830)
# 18630                                1.5 L, Blue, Silver   3.9     (2,845)
# 18631                                              Black   3.9       (511)
#
#       Discounts   Prices
# 0       41% off  ₹20,990
# 1       81% off     ₹292
# 2       38% off  ₹17,990
# 3       65% off   ₹1,249
# 4       56% off   ₹1,099
# ...         ...      ...
# 18627   62% off   ₹1,299
# 18628   62% off     ₹239
# 18629   51% off   ₹1,999
# 18630   72% off     ₹999
# 18631   78% off     ₹426
#
# [18632 rows x 6 columns]

# %%
df
# Out:
#                                                   Titles  \
# 0      Midea TORRINO,WQP12-5201F Free Standing 13 Pla...
# 1      Venus Electronic Digital Kitchen Weight Machin...
# 2      Midea MDWTT0802D(B) Free Standing 8 Place Sett...
# 3                 Sansui Plus 500 W Juicer Mixer Grinder
# 4                 Lifelong Power Pro 500 W Mixer Grinder
# ...                                                  ...
# 18627  Moonstruck mixi blue - 4 jar 750 W Juicer Mixe...
# 18628  SONALEX Weight Machine 10kg Scale Digital For ...
# 18629  HAVELLS GHFMGCIK050 / GHFMGCIE050 500 W Mixer ...
# 18630  Flipkart SmartBuy Storm Max PowerChef 500 W Ju...
# 18631  CHHOKRA Digital 10kg x 1g Kitchen Scale Balanc...
#
#                                                   Colors Stars     Reviews  \
# 0                                                  White   3.9     (2,480)
# 1                     Allure Plus | 3 Jars | Black, Blue   3.9     (2,199)
# 2                     Power Pro - LLMG20 | 3 Jars | Blue   3.9     (2,480)
# 3            ACGM-DS500W BLEND | 4 Jars | Black and Blue   4.1    (56,010)
# 4         Rapid plus / Rapid Plus 5J | 5 Jars | Ink Blue   4.1  (1,61,416)
# ...                                                  ...   ...         ...
# 18627  Black, Infrared Induction 2000 Watt (All Utens...   4.1     (9,294)
# 18628                                 MS23A3513AK, BLACK   4.4    (12,051)
# 18629                               Plus | 1 Jar | Black     4    (28,830)
# 18630                                1.5 L, Blue, Silver   3.9     (2,845)
# 18631                                              Black   3.9       (511)
#
#       Discounts   Prices
# 0       41% off  ₹20,990
# 1       81% off     ₹292
# 2       38% off  ₹17,990
# 3       65% off   ₹1,249
# 4       56% off   ₹1,099
# ...         ...      ...
# 18627   62% off   ₹1,299
# 18628   62% off     ₹239
# 18629   51% off   ₹1,999
# 18630   72% off     ₹999
# 18631   78% off     ₹426
#
# [18632 rows x 6 columns]

# %%
df.shape
# Out:
# (18632, 6)

# %%
df.to_csv(r"C:\Users\Administrator\OneDrive\Documents\Projects\KitchenAppliances.csv",index=False)
