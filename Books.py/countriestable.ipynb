# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
web="https://www.worldometers.info/world-population/population-by-country/"
path=r"C:\Users\Administrator\OneDrive\Documents\Data_Entry\PythonDOCS\chromedriver.exe"
service=Service(executable_path=path)
driver=webdriver.Chrome(service=service)
driver.get(web)
time.sleep(2)

# %%
country=driver.find_elements(By.XPATH,"(//tbody/tr/td[2]/a)")
population=driver.find_elements(By.XPATH,"(//tbody/tr/td[3])")
yearly_change=driver.find_elements(By.XPATH,"(//tbody/tr/td[4])")
net_change=driver.find_elements(By.XPATH,"(//tbody/tr/td[5])")
density=driver.find_elements(By.XPATH,"(//tbody/tr/td[6])")
land_area=driver.find_elements(By.XPATH,"(//tbody/tr/td[7])")
migrants=driver.find_elements(By.XPATH,"(//tbody/tr/td[8])")
fertility_rate=driver.find_elements(By.XPATH,"(//tbody/tr/td[9])")
age=driver.find_elements(By.XPATH,"(//tbody/tr/td[10])")
urban_population=driver.find_elements(By.XPATH,"(//tbody/tr/td[11])")
world_share=driver.find_elements(By.XPATH,"(//tbody/tr/td[12])")

# %%
population_results=[]
for i in range (len(country)):
  temporary_data={'Country':country[i].text,
                  'Population':population[1].text,
                  'Yearly change':yearly_change[i].text,
                  'Net change':net_change[i].text,
                  'Density':density[i].text,
                  'Land area':land_area[i].text,
                  'Migrants':migrants[i].text,
                  'Fertility rate':fertility_rate[i].text,
                  'Age':age[i].text,
                  'Urban population':urban_population[i].text,
                  'World share':world_share[i].text}
  population_results.append(temporary_data)

# %%
df_data=pd.DataFrame(population_results)

# %%
print(df_data)
# Out:
#               Country     Population Yearly change  Net change Density  \
# 0               India  1,419,321,278        0.89 %  12,866,195     488
# 1               China  1,419,321,278       -0.23 %  -3,263,655     151
# 2       United States  1,419,321,278        0.57 %   1,949,236      38
# 3           Indonesia  1,419,321,278        0.82 %   2,297,864     156
# 4            Pakistan  1,419,321,278        1.52 %   3,764,669     326
# ..                ...            ...           ...         ...     ...
# 229        Montserrat  1,419,321,278       -0.70 %         -31      44
# 230  Falkland Islands  1,419,321,278       -0.20 %          -7       0
# 231           Tokelau  1,419,321,278        4.55 %         109     251
# 232              Niue  1,419,321,278        0.11 %           2       7
# 233          Holy See  1,419,321,278        0.00 %           0   1,240
#
#      Land area    Migrants Fertility rate Age Urban population World share
# 0    2,973,190    -630,830            2.0  28             37 %     17.78 %
# 1    9,388,211    -318,992            1.0  40             66 %     17.39 %
# 2    9,147,420   1,286,132            1.6  38             82 %      4.23 %
# 3    1,811,570     -38,469            2.1  30             59 %      3.47 %
# 4      770,880  -1,401,173            3.5  20             34 %      3.08 %
# ..         ...         ...            ...  ..              ...         ...
# 229        100          -7            1.4  42             11 %      0.00 %
# 230     12,170         -13            1.7  42             68 %      0.00 %
# 231         10          72            2.6  27              0 %      0.00 %
# 232        260          10            2.5  36             44 %      0.00 %
# 233          0          18            1.0  59             N.A.      0.00 %
#
# [234 rows x 11 columns]

# %%
df_data
# Out:
#               Country     Population Yearly change  Net change Density  \
# 0               India  1,419,321,278        0.89 %  12,866,195     488
# 1               China  1,419,321,278       -0.23 %  -3,263,655     151
# 2       United States  1,419,321,278        0.57 %   1,949,236      38
# 3           Indonesia  1,419,321,278        0.82 %   2,297,864     156
# 4            Pakistan  1,419,321,278        1.52 %   3,764,669     326
# ..                ...            ...           ...         ...     ...
# 229        Montserrat  1,419,321,278       -0.70 %         -31      44
# 230  Falkland Islands  1,419,321,278       -0.20 %          -7       0
# 231           Tokelau  1,419,321,278        4.55 %         109     251
# 232              Niue  1,419,321,278        0.11 %           2       7
# 233          Holy See  1,419,321,278        0.00 %           0   1,240
#
#      Land area    Migrants Fertility rate Age Urban population World share
# 0    2,973,190    -630,830            2.0  28             37 %     17.78 %
# 1    9,388,211    -318,992            1.0  40             66 %     17.39 %
# 2    9,147,420   1,286,132            1.6  38             82 %      4.23 %
# 3    1,811,570     -38,469            2.1  30             59 %      3.47 %
# 4      770,880  -1,401,173            3.5  20             34 %      3.08 %
# ..         ...         ...            ...  ..              ...         ...
# 229        100          -7            1.4  42             11 %      0.00 %
# 230     12,170         -13            1.7  42             68 %      0.00 %
# 231         10          72            2.6  27              0 %      0.00 %
# 232        260          10            2.5  36             44 %      0.00 %
# 233          0          18            1.0  59             N.A.      0.00 %
#
# [234 rows x 11 columns]

# %%
df_data.to_csv(r"C:\Users\Administrator\OneDrive\Documents\WebTables\World Population.csv",index=False)
