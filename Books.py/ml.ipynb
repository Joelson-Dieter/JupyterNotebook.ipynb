# %%
import numpy as np
speed=[99,86,87,88,111,86,103,87,94,78,77,85,86]
x=np.mean(speed)
print(x)
# Out:
# 89.76923076923077

# %%
speed=[100,300,200,400,300,900,645]
y=np.mean(speed)
print(y)
# Out:
# 406.42857142857144

# %%
speed=[1,2,3,4,5,6,7,8,9,7,8,9,4,5,6,1,2,3,45,5,6]
z=np.mean(speed)
print(z)
# Out:
# 6.9523809523809526

# %%
speed=[30,20,30,40,50,56,45,67,89]
a=np.mean(speed)
print(a)
# Out:
# 47.44444444444444

# %%
speed=[99,86,87,88,111,86,103,87,94,78,77,85,85,85,85,86]
x=np.median(speed)
print(x)
# Out:
# 86.0

# %%
speed=[99,86,87,88,111,86,103,87,94,78,77,85,86]
x=np.median(speed)
print(x)
# Out:
# 87.0

# %%
from scipy import stats
speed=[99,86,87,88,111,86,103,87,94,78,77,85,86]
x=stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=86, count=3)

# %%
speed=[99,86,87,88,111,86,103,87,94,78,77,85,85,85,85,86]
x=stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=85, count=4)

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.uniform(0.0,5.0,250)
plt.hist(x,5)
plt.show()

# %%
x=np.random.uniform(0.0,5.0,100000)
plt.hist(x,100)
plt.show()
