# %%
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

web="https://www.flipkart.com/industrial-scientific-supplies/lab-scientific-products/pr?sid=gsx,l9d&p[]=facets.serviceability%5B%5D%3Dtrue&otracker=categorytree&otracker=nmenu_sub_Sports%2C%20Books%20%26%20More_0_Lab%20%26%20Scientific%20Products"
path=r"C:\Users\Administrator\OneDrive\Documents\Data_Entry\PythonDOCS\chromedriver.exe"

service=Service(executable_path=path)
driver=webdriver.Chrome(service=service)

driver.get(web)
time.sleep(2)


titles=[]
stars=[]
reviews=[]
discounts=[]
prices=[]

# %%
for i in range (491):
  title=driver.find_elements(By.XPATH,"(//a[@class='wjcEIp'])")
  star=driver.find_elements(By.XPATH,"(//div[@class='XQDdHH'])")
  review=driver.find_elements(By.XPATH,"(//span[@class='Wphh3N'])")
  discount=driver.find_elements(By.XPATH,"(//div[@class='UkUFwK'])")
  price=driver.find_elements(By.XPATH,"(//div[@class='Nx9bqj'])")

  for t in title:
    titles.append(t.text)

  for s in star:
    stars.append(s.text)

  for r in review:
    reviews.append(r.text)

  for d in discount:
    discounts.append(d.text)

  for p in price:
    prices.append(p.text)

next_button=driver.find_element(By.XPATH,"(//a[@class='_9QVEpD'])")
next_button.click()
time.sleep(2)

# %%
min_len=min(len(titles),len(stars),len(reviews),len(discounts),len(prices))
titles=titles[:min_len]
stars=stars[:min_len]
reviews=reviews[:min_len]
discounts=discounts[:min_len]
prices=prices[:min_len]

df = pd.DataFrame({
    'Titles': titles,
    'Stars': stars,
    'Reviews': reviews,
    'Discounts': discounts,
      'Prices': prices})
print(df)
df

df.to_csv(r"C:\Users\Administrator\OneDrive\Documents\Projects\LabProducts.csv",index=False)
# Out:
#                                                   Titles Stars  Reviews  \
# 0        konvio neer Pen Type Tds 0012 Digital TDS Meter   4.1  (3,676)
# 1      AMPEREUS Digital Water TDS EC and Temperature ...   4.1    (818)
# 2      LISAMED Adult Enema kit for Home use with Inst...   4.2    (104)
# 3      KEKROWN Toshiba Pair of 2SC 5200 + 2SA 1943 15...   4.2     (39)
# 4      The greenland mushroom Digital Hygrometer Ther...     4    (851)
# ...                                                  ...   ...      ...
# 18162  LISAMED Adult Enema kit for Home use with Inst...   4.5     (13)
# 18163  KEKROWN Toshiba Pair of 2SC 5200 + 2SA 1943 15...     5      (5)
# 18164  The greenland mushroom Digital Hygrometer Ther...   4.2    (117)
# 18165  SSUCA Energy Meter 6 in 1, 40-300V AC 100A Wat...   4.3     (33)
# 18166                            PRAGATI TRENDS Lab Coat   3.8     (84)
#
#       Discounts  Prices
# 0       62% off    ₹299
# 1       70% off    ₹297
# 2       79% off    ₹249
# 3       24% off    ₹376
# 4       40% off    ₹298
# ...         ...     ...
# 18162   79% off    ₹249
# 18163   24% off    ₹376
# 18164   40% off    ₹298
# 18165   56% off  ₹1,299
# 18166   62% off    ₹379
#
# [18167 rows x 5 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.shape
#
# NameError: name 'df' is not defined
