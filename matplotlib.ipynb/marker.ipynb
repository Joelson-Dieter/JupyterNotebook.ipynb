# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
ypoint = np.array ([3,8,1,10])
plt.plot(ypoint,marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoint = np.array ([2,3,5,7,])
plt.plot (ypoint,marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoint = np.array ([3,8,1,10])
plt.plot(ypoint,marker = 'o',ms=15,mec='red',mfc='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([2,4,5,8,2])
plt.plot(ypoints,marker='o',ms=10,mec='g',mfc='m')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array ([3,8,1,10,8])
plt.plot(ypoints,marker='o',mec='r',mfc='g',ms=10.5,ls='dotted',lw='5.7',c='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array ([3,8,1,10])
plt.plot(ypoints,marker='*',ms=20,mec='r',mfc='b',ls='dashed',lw='1.5',c='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array ([3,8,1,10])
y2 = np.array ([6,2,7,11])

plt.plot(y1,c='y',ls='dashed')
plt.plot(y2,c='r',ls='dotted')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1=np.array ([0,1,2,3])
y1=np.array ([3,8,1,10])
x2=np.array ([0,1,2,3,])
y2=np.array ([6,2,7,11])

plt.plot(x1,y1,x2,y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([80,85,90,95,100,105,110,120,125,130])
y=np.array([240,250,260,270,280,290,300,310,320,330])

plt.plot (x,y)
plt.xlabel("Average Plus")
plt.ylabel ("Calorie Burnage")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([20,30,40,50,60])
y=np.array([100,105,110,120,130])

plt.plot(x,y)
plt.title("Daily Routine Treatment",color='r',size=10)
plt.xlabel("Blood sugar",color='r',size='10')
plt.ylabel("Average Calorie Burnage",color='r',size=10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,30,10,30,10,25])
y=np.array([20,30,40,50,60,70])
plt.plot(x,y)
plt.title("End term Performance",color='y',size=20,loc='left')
plt.xlabel("Average marks",color='y',size=20)
plt.ylabel("Minimum Markd",color='y',size=20)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([40,30,50,60,70,20,35])
y=np.array([50,55,60,65,70,75,80,])
plt.title("Sports Watch",loc='right')
plt.xlabel("Average Pulse",color='g',size=10)
plt.ylabel("Calorie Burnage",color='g',size=10)
plt.plot(x,y,ls='dotted',lw=2,c='b',marker='o',ms=5,mec='r',mfc='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array ([80,85,90,95,100,105,110,115,120,130,135])
y=np.array ([240,250,260,270,280,290,300,310,320,330,340])

plt.title ('ASports watch data',color='r',size=10,loc='left')
plt.xlabel ('Average pulse',color='r',size=10)
plt.ylabel ('Calorie burnage',color='r',size=10)
plt.plot(x,y,color='y',linewidth=5,linestyle='dotted')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([80,85,90,95,100,105,110,120,125,130])
y=np.array([100,150,200,250,300,350,400,450,500,550])
plt.title('Games played')
plt.xlabel('Number of goals')
plt.ylabel('Number of players')
plt.plot(x,y)
plt.grid(axis='x',color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([10,30,30,43,25])
y=([100,200,300,400,500])
plt.title('Players')
plt.xlabel('globals')
plt.ylabel('Goels scored')
plt.plot(x,y)
plt.grid(axis='y',color='yellow',linestyle='--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=([20,21,24,45,17])
y=([30,40,50,60,70])
plt.title('Students',color='g',size=10,loc='left')
plt.xlabel('Exams sat',color='g',size=10)
plt.ylabel('Scores',color='g',size=10)
plt.plot(x,y)
plt.grid(color='red',linestyle='--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([1, 2, 3, 4])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 1)
plt.plot(x, y)
x = np.array([1, 2, 3, 4])
y = np.array([5, 10, 15, 20])
plt.subplot(1, 2, 2)
plt.plot(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,4])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([4,8,2,10])
plt.subplot(2,1,1)
plt.plot(x,y)
x=([0,1,2,3])
y=np.array([50,60,70,80])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,2,3,4])
y=np.array([30,40,50,60])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([1,2,3,4])
y=np.array([40,50,60,70])
plt.subplot(2,1,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([8,3,1,10])
y=np.array([20,25,26,30])
plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([8,3,1,10])
y=np.array([30,40,50,60])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])

plt.subplot(2,3,1)

x=np.array([0,1,2,3])

y=np.array([10,20,30,40])

plt.subplot(2,3,1)

plt.plot(x,y)

x=np.array([0,1,2,3])

y=np.array([5,10,15,20])

plt.subplot(2,3,2)

plt.plot(x,y)

x=np.array([0,1,2,3])

y=np.array([10,20,30,40])

plt.subplot(2,3,3)

plt.plot(x,y)

x=np.array([0,1,2,3])

y=np.array([5,10,15,20])

plt.subplot(2,3,4)

plt.plot(x,y)

x=np.array([0,1,2,3])

y=np.array([10,20,30,40])

plt.subplot(2,3,5)

plt.plot(x,y)

x=np.array([0,1,2,3])

y=np.array([5,10,15,20])

plt.subplot(2,3,6)

plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([1,2,3,4])

y=np.array([30,40,50,60])

plt.subplot(2,3,1)

plt.title("SALES")

plt.plot(x,y)

plt.plot(x,y)

x=np.array([1,2,3,4])

y=np.array([40,50,60,70])

plt.subplot(1,2,2)

plt.title("EXPENSES")

plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

import sys

x=np.array([0,1,2,3])

y=np.array([3,8,1,10])

plt.subplot(1,2,1)

plt.title("SALES")

plt.plot(x,y)

x=np.array([0,1,2,3,4])

y=np.array([10,20,30,40,50])

plt.subplot(1,2,2)

plt.title("EXPENSES")

plt.plot(x,y)

plt.suptitle("MY SHOP")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,87,])

plt.scatter(x,y)

plt.title("Temperature vs Sales")

plt.xlabel("Temperature") 

plt.ylabel("Sales")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y=np.array([99,86,87,88,111,86,103,87,94,78,77,85,87,])



plt.scatter(x,y,color = 'black')

plt.title("Temperature vs Sales")

plt.xlabel("Temperature")

plt.ylabel("Sales")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

plt.scatter(x, y)

x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])

y=np.array([100,105,84,105,90,99,95,94,100,79,112,91,80,85,87])

plt.scatter(x, y)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

plt.scatter(x, y, color = 'black')

x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])

y=np.array([100,105,84,105,90,99,95,94,100,79,112,91,80,85,87])

plt.scatter(x, y, color ='red')

plt.title("Temperature vs Sales")

plt.xlabel("Temperature")

plt.ylabel("Sales")

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

plt.scatter(x, y, color = 'blue')

x=np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])

y=np.array([100,105,84,105,90,99,95,94,100,79,112,91,80,85,87])

plt.scatter(x, y, color ='yellow')

plt.title("Temperature vs Sales")

plt.xlabel("Temperature")

plt.ylabel("Sales")

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

colors = np.array(['red','yellow','green','blue','orange','purple','gray','cyan','white','magenta','beige','pink','black'])

plt.scatter(x, y, c=colors)

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

colors = np.array([0,10,20,30,40,45,50,55,60,70,80,90,100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

colors = np.array([0,10,20,30,35,40,45,50,60,70,80,90,100])

plt.scatter(x, y, c=colors, cmap='viridis')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

colors = np.array([0,10,20,30,35,40,45,50,60,70,80,90,100])

plt.scatter(x, y, c=colors, cmap='magma')

plt.colorbar()


plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

colors = np.array(['red','blue','green','yellow','pink','orange','purple','gray','green','yellow','gray','purple','pink'])

plt.scatter(x, y, c=colors, cmap='flag')

plt.colorbar()

plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1568\2978186371.py:11: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c=colors, cmap='flag')

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])

y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,85])

colors = np.array([10,20,25,30,35,40,45,50,60,70,80,30,90])  

sizes = np.array([20,30,40,300,335,30,30,100,30,30 ,30,200,30])

plt.scatter(x, y, c=colors, cmap='magma',s=sizes,alpha = 0.5)

plt.title  ('Racing cars', fontsize = 24, fontweight = 'bold')

plt.xlabel('Number of cars', fontsize = 24,fontweight = 'bold')

plt.ylabel ('Number of races', fontsize = 24,fontweight = 'bold')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.random.randint(100,size=(1000))

y = np.random.randint(100,size=(1000))

colors = np.random.randint(100,size=(1000))

sizes = np.random.randint(100,size=(1000))

plt.scatter(x, y, c=colors, cmap='magma',s=sizes,alpha = 0.5)

plt.title  ('Random scatter plot', fontsize = 24, fontweight = 'bold')

plt.xlabel('X-axis', fontsize = 24,fontweight = 'bold')

plt.ylabel ('Y-axis', fontsize = 24,fontweight = 'bold')

plt.scatter(x,y,c=colors,s=sizes,alpha=0.5,cmap='nipy_spectral')

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.random.randint(100,size=(1000))

y = np.random.randint(100,size=(1000))

colors = np.random.randint(100,size=(1000))

sizes = np.random.randint(100,size=(1000))

plt.title('Cars', fontsize=10, fontweight='bold',loc='left',color='red')

plt.xlabel('Number of cars', fontsize=10, fontweight='bold',color='red')

plt.ylabel('Speed', fontsize=10, fontweight='bold',color='red')

plt.scatter(x, y, c=colors, cmap='plasma',s=sizes,alpha = 0.5)

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.random.randint(50,size=(500))

y = np.random.randint(50,size=(500))

colors = np.random.randint(100,size=(500))

sizes = np.random.randint(100,size=(500))

plt.title('Random scatter plot', fontsize=10, fontweight='bold',loc='left',color='red')

plt.xlabel('X-axis', fontsize=10, fontweight='bold', color='red')

plt.ylabel('Y-axis', fontsize=10, fontweight='bold', color='red')

plt.scatter(x, y, c=colors, cmap='viridis',s=sizes,alpha = 0.5)

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.array (['A', 'B', 'C', 'D', 'E'])

y = np.array([20, 30, 10, 40, 50])

plt.bar(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x=np.array(['BANANAS','APPLES'])

y=np.array([400,350])

plt.bar(x,y,width=0.2)

plt.title('Bananas/Fruits', fontsize = 10, fontweight = 'bold',color='red',loc='left')

plt.xlabel('Fruit', fontsize = 10, fontweight = 'bold',color='red')

plt.ylabel('Quantity', fontsize = 10, fontweight = 'bold',color='red')

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x=np.array(['BANANAS','APPLES','ORANGES'])

y=np.array([400,350,250])

plt.barh(x,y,color='yellow')

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x=np.array(['BANANAS','APPLES','ORANGES'])  

y=np.array([400,350,250])

plt.barh(x, y, color='red',height=0.3)

plt.title('Fruits', fontsize = 10, fontweight = 'bold',color='red',loc='left')

plt.xlabel('Fruit', fontsize = 10, fontweight = 'bold',color='red')

plt.ylabel('Quantity', fontsize = 10, fontweight = 'bold',color='red')

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x=np.array(['BANANAS','APPLES','ORANGES'])

y=np.array([400,350,250])

plt.bar(x, y, color='orange', width=0.3)

plt.title('Fruits', fontsize = 10, fontweight = 'bold',color='red',loc='left')

plt.xlabel('Fruit', fontsize = 10, fontweight = 'bold',color='red')

plt.ylabel('Quantity', fontsize = 10, fontweight = 'bold',color='red')

plt.show()

# %%
import numpy as np

x = np.random.normal(170,10,250)

print(x)
# Out:
# [182.19540396 174.19500504 171.197686   176.99956197 180.33864444
#  177.52675099 176.45403747 164.40168378 174.91018125 161.02467692
#  170.54088754 174.41342973 175.03991251 171.21310264 175.46261619
#  153.86838477 165.53541345 174.07562901 165.50811231 174.67153067
#  156.70563029 178.26797918 184.29390073 169.29948601 163.53662949
#  177.75817596 164.94103632 174.30796484 170.70635443 162.36726047
#  182.00610535 164.02467378 151.65790456 174.99516625 183.43566604
#  166.4830379  164.89846572 162.13617042 159.8914108  153.68891393
#  172.638897   171.18278174 165.90250925 177.42972797 176.75098159
#  148.80139015 174.08536094 177.25452747 173.96566087 143.95110731
#  175.22784974 185.73797244 168.98668762 169.77953919 160.70271792
#  169.46643994 174.42864535 164.00881754 159.29328181 163.35320885
#  170.14640738 178.2056909  172.98279856 164.41085816 172.95193218
#  169.53834679 170.73536587 151.20585186 186.03842385 174.91341855
# ...

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.random.normal(170,10,250)

plt.hist(x, bins=20, color='yellow', edgecolor='black')

plt.title('Normal distribution', fontsize = 10, fontweight = 'bold',color='red')

plt.xlabel('Value', fontsize = 10, fontweight = 'bold',color='red')

plt.ylabel('Frequency', fontsize = 10, fontweight = 'bold',color='red')

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

x = np.random.normal(120,10,290)

plt.hist(x,)

plt.show()

# %%
import numpy as np

x = np.random.normal(120,10,290)

print(x)
# Out:
# [124.08762979 112.55459668 123.24828441 119.86433916 115.16385044
#  130.7473865  117.75173197 137.48386963 121.59433103 128.37571679
#  122.6213689  121.74072498 114.82632841 133.35098753 123.21171507
#  118.40227071 128.06934127 120.11682877 112.37566167 120.9731857
#  122.61342793 130.96788591 131.82757297 121.58509177 123.09491333
#  128.59904846 105.5243167  120.6170227  122.8737363  109.13356318
#  134.31873978 113.05841089 121.34166713 122.46463072 120.55404465
#  129.74487719 100.70474264 126.05065879 104.09632792 117.27743529
#  117.05416651 127.48304427 136.27064737 125.32795992 114.651827
#  116.02678982 132.5171441  113.0510197  121.85288182 140.79602437
#  129.50299227 114.59709579 105.65527211  99.29964397 112.39119911
#  139.09271841  96.22758257 123.67626675 119.56247514 133.99124414
#  120.46008413 133.39409823 127.88836704 110.5400767  101.80532327
#   98.48802872 105.66123413 124.9615638  119.90757542 104.87944
# ...

# %%
import matplotlib.pyplot as plt

import numpy as np

y=np.array([30,25,25,15])

plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

y=np.array([30,25,25,15])

mylabels = ['Apples','Bananas','Mangoes','Pineapples']

plt.pie(y,labels=mylabels)

plt.show()

# %%
import matplotlib.pyplot as plt

import numpy as np

y=np.array([30,25,25,15])

mylabels = ['Apples','Bananas','Mangoes','Pineapples']

plt.pie(y,labels = mylabels,startangle=90)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([30,25,25,15])

mylabels = ['Apples','Bananas','Mangoes','Pineapples']
myexplode =[0.2,0.3,0,0.2]
plt.pie(y,labels=mylabels,explode=myexplode,shadow=True)
plt.show()
